# %%
import matplotlib as mpl
import seaborn as sns
import random

import matplotlib.pyplot as plt

# 在Jupyter Notebook上顯示圖表所必需的Magic Command
# %matplotlib inline

# %%
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame
import math

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# %precision 3
# Out:
# '%.3f'

# %% [markdown]
# #### 2-5-2散佈圖

# %%
# 散佈圖

random.seed(0)

# x軸的資料
x = np.random.randn(30)

# y軸的資料
y = np.sin(x) + np.random.randn(30)

# 指定圖形的大小(請試著修改20或6)
plt.figure(figsize=(20,6))

# 描繪圖形
plt.plot(x,y,'o')

# 也能如下描繪散佈圖
plt.scatter(x,y)

# 標題
plt.title('Title Name')
# X軸標籤
plt.xlabel('X')
# Y軸標籤
plt.ylabel('Y')

# 顯示grid(圖形中的格線)
plt.grid(True)

# %%
np.random.seed(0)

# 資料的範圍
numpy_data_x = np.arange(1000)
# 生成亂數與累積和
numpy_ranom_data_y = np.random.randn(1000).cumsum()
# 指定圖形大小
plt.figure(figsize=(20,6))
# 可藉由label=與legend來加上標籤
plt.plot(numpy_data_x, numpy_ranom_data_y,label='Label')
plt.legend()

plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)

# %% [markdown]
# #### 2-5-3圖形的分割

# %%
# 指定圖形大小
plt.figure(figsize=(20,6))

# 2列1行圖形的第1個
plt.subplot(2,1,1)
x = np.linspace(-10,10,100)
plt.plot(x,np.sin(x))

# 2列1行圖形的第2個
plt.subplot(2,1,2)
y = np.linspace(-10,10,10000)
plt.plot(y,np.sinc(2*y))

plt.grid()

# %%
def my_function(x):
    return x ** 2 + 2 * x + 1

x = np.arange(-10,10)
plt.figure(figsize=(20,6))
plt.plot(x,my_function(x))
plt.grid(True)

# %% [markdown]
# #### 2-5-5直方圖

# %%
random.seed(0)

plt.figure(figsize=(20,6))
# 描繪直方圖
plt.hist(np.random.randn(10 ** 5 ) * 10 + 50,bins = 60,range = (20,80))

plt.grid(True)

# %%
# ?plt.hist

# %% [markdown]
# ##### 練習問題2-10
